# %% [markdown]
# ## TASK 1: Setup Environment
# 1. create a dedicated virtual environment called "DMML_AY2526" with python version 3.10 <br><br>
# 2. install the following packages:
#     - `jupyter`, `pandas`, `openpyxl`, `seaborn`, `matplotlib`, `scikit-learn`, `plotly`
# <br><br>
# 3. enjoy your creation:
#     - Create a directory for the course exercises.
#     - Inside, create a new jupyter notebook.
#     - Type `import this` in a cell code and execute it.
#     - Enjoy ***The Zen of Python***.

# %% [markdown]
# You have 20 minutes

# %% [markdown]
# ## Steps:
# 1. download anaconda
# 2. go to your shell prompt (for Windows, you have dedicated one) and create the environment
# 3. activate the environment
# 4. install packages (with conda or pip)

# %% [markdown]
# 5. Perform the following steps:
#     - Create a directory for the course exercises.
#     - Inside, create a new jupyter notebook.
#     - Type `import this` in a cell code and execute it.
#     - Enjoy ***The Zen of Python***.

# %% [markdown]
# ## Answers:
#
# <details>
# <summary>Click to reveal the answer</summary>
#
# One-line-for-all
#
# ```bash
# $ conda create --name DMML_AY2526 python=3.10 jupyter pandas openpyxl seaborn matplotlib scikit-learn plotly
# $ conda activate DMML_AY2526
# ```
#
#
# Baby steps
#
# ```bash
# $ conda create --name DMML_AY2526 python=3.10
# $ conda activate DMML_AY2526
# $ (DMML_AY2526) conda install jupyter pandas openpyxl seaborn matplotlib scikit-learn plotly
# ```
#
#
#
# </details>
