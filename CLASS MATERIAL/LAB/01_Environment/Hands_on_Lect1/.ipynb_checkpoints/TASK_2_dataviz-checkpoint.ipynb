# %% [markdown]
# # TASK
# STEP 0: define Goal: practice with visual data exploration

# %% [markdown]
# # Your turn
# ### Scenario: You are playing with your 10-years old nephew, and suddenly he asks you: "I want to understand the content of the file data/composers.xlsx, sheet=Sheet_students_explo ". (Your nephew is very precise)
#
# #### TODO 1: Explore Sheet_students_explo sheet in file sheet=Sheet_students_explo ".
#
# Answer to you nephew good questions:
# "What do you want to tell me with this specific plot? Why are you using that kind of plot and not another kind? "
#
# 1. are there missing values?
# 2. are there not-reasonable values?
# 3. how can I treat them?
#
# #### TODO 2:
# - a) Make a list of useful plots for data exploration, describe their goal;
# - b) choose some plot to describe the content of the file and show them
#
#
# you have 7-15 minutes

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data acquisition
# hint: to acquire data, you can use
#
# df_explo = pd.read_excel('dataset/composers.xlsx', index_col = 'composer', sheet_name='Sheet_students_explo',
#                              na_values=['unknown'])

# %% [markdown]
# ## Data exploration

# %%
# look at the first seven rows

# %%
# check general info and columns type

# %%
# check for nans

# %%
## Question: if nans are present, should we fill them? How? Or do we remove?

# %%
# check statistics

# %%
# Can we say something about the distributions of each feature?

# %%
# check for duplicates

# %%
# question: what do we do if we find duplicates?

# %% [markdown]
# ### DataViz
# Make a list of useful plots for data exploration, describe their goal;

# %%
#print list here....

# %% [markdown]
# *choose* some kinds of plot to describe the content of the file and plot them

# %% [markdown]
# # What can we say about the dataset, after looking at the plots?
