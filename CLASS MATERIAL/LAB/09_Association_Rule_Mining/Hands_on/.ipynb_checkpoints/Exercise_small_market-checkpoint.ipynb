# %%
import random
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# Generate Synthetic Transactions in a small market scenario

# %%
# acquire dataset
df = pd.read_csv("market_dataset.csv", index_col=0)
df
# Out:
#       beer  bread  coffee  diapers   milk  water
# 0     True   True    True    False   True   True
# 1     True  False    True     True  False  False
# 2    False  False   False    False   True  False
# 3    False  False   False     True  False  False
# 4     True  False   False    False   True  False
# ..     ...    ...     ...      ...    ...    ...
# 295  False  False   False    False  False  False
# 296   True   True   False    False  False   True
# 297  False  False   False    False  False  False
# 298  False   True   False    False   True  False
# 299  False  False    True    False   True   True
#
# [300 rows x 6 columns]

# %%
# get frequent itemset
frequent_itemsets = apriori(df, min_support=0.07, use_colnames=True)
frequent_itemsets.sort_values("support", ascending=False).head(10)
# Out:
#      support         itemsets
# 1   0.463333          (bread)
# 4   0.396667           (milk)
# 0   0.366667           (beer)
# 5   0.353333          (water)
# 2   0.283333         (coffee)
# 3   0.223333        (diapers)
# 13  0.200000    (bread, milk)
# 6   0.176667    (bread, beer)
# 8   0.173333  (beer, diapers)
# 14  0.166667   (bread, water)

# %%
# calculate association rules

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
rules.sort_values(["confidence", "lift"], ascending=False).head(10)
# Out:
#          antecedents consequents  antecedent support  consequent support  \
# 21  (bread, diapers)      (beer)            0.096667            0.366667
# 33   (milk, diapers)      (beer)            0.093333            0.366667
# 5          (diapers)      (beer)            0.223333            0.366667
# 28      (milk, beer)     (bread)            0.153333            0.463333
# 9             (milk)     (bread)            0.396667            0.463333
# 40     (milk, water)     (bread)            0.153333            0.463333
# 1             (beer)     (bread)            0.366667            0.463333
# 22   (beer, diapers)     (bread)            0.173333            0.463333
# 32      (milk, beer)   (diapers)            0.153333            0.223333
# 4             (beer)   (diapers)            0.366667            0.223333
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 21  0.083333    0.862069  2.351097               1.0  0.047889    4.591667
# ...

# %%
import plotly.io as pio
pio.renderers.default = 'notebook'

# %%
import plotly.express as px

#rules_plot = rules.sort_values("confidence", ascending=False).head(15).copy()
rules_plot = rules.sort_values("confidence", ascending=False).copy()

# Convert frozensets to strings for Plotly
rules_plot["antecedents_str"] = rules_plot["antecedents"].apply(lambda x: ", ".join(list(x)))
rules_plot["consequents_str"] = rules_plot["consequents"].apply(lambda x: ", ".join(list(x)))


fig = px.scatter(
    rules_plot,
    x="support",
    y="confidence",
    size="lift",
    #hover_name="antecedents_str",
    hover_data={
        "antecedents_str": True,
        "consequents_str": True,
        "support": ":.3f",
        "confidence": ":.3f",
        "lift": ":.3f"
    },
    title="Association Rules: Support vs Confidence (Bubble size = Lift)",
    width=800, height=600
)

fig.update_layout(
    xaxis_title="Support",
    yaxis_title="Confidence",
    template="plotly_white"
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="17d83912-0e16-418d-b750-64d43b0f1fda" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("17d83912-0e16-418d-b750-64d43b0f1fda")) {                    Plotly.newPlot(                        "17d83912-0e16-418d-b750-64d43b0f1fda",                        [{"customdata":[["bread, diapers","beer",2.3510971786833856],["milk, diapers","beer",2.142857142857143],["diapers","beer",2.1166892808683855],["milk, beer","bread",1.1729746637472631],["milk","bread",1.0882050661991416],["milk, water","bread",1.0791
# ...

# %%
import plotly.express as px

#rules_plot = rules.sort_values("confidence", ascending=False).head(15).copy()
rules_plot = rules.sort_values("confidence", ascending=False).copy()

# Convert frozensets to strings for Plotly
rules_plot["antecedents_str"] = rules_plot["antecedents"].apply(lambda x: ", ".join(list(x)))
rules_plot["consequents_str"] = rules_plot["consequents"].apply(lambda x: ", ".join(list(x)))
rules_plot["antecedents_len"] = rules_plot["antecedents"].apply(len)
rules_plot["consequents_len"] = rules_plot["consequents"].apply(len)
rules_plot["rule_len"] = rules_plot["consequents_len"] + rules_plot["antecedents_len"]


fig = px.scatter(
    rules_plot,
    x="support",
    y="confidence",
    size="lift",
    color="rule_len",
    #hover_name="antecedents_str",
    color_continuous_scale=["grey", "cyan"],
    hover_data={
        "antecedents_str": True,
        "consequents_str": True,
        "support": ":.3f",
        "confidence": ":.3f",
        "lift": ":.3f"
    },
    title="Association Rules: Support vs Confidence (Bubble size = Lift, color= #elements in the rule)",
    width=800, height=600
)

fig.update_layout(
    xaxis_title="Support",
    yaxis_title="Confidence",
    template="plotly_white"
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="4e3b31aa-fdbf-4a4a-80d6-13135e2aa1f9" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4e3b31aa-fdbf-4a4a-80d6-13135e2aa1f9")) {                    Plotly.newPlot(                        "4e3b31aa-fdbf-4a4a-80d6-13135e2aa1f9",                        [{"customdata":[["bread, diapers","beer",2.3510971786833856],["milk, diapers","beer",2.142857142857143],["diapers","beer",2.1166892808683855],["milk, beer","bread",1.1729746637472631],["milk","bread",1.0882050661991416],["milk, water","bread",1.0791
# ...

# %% [markdown]
# ## Comments:
#
# From the results, we can observe how "diapers" + "beer" have high lift, high support and high confidence, possibly indicating an interesting underlying phenomenon (you are a dad!)
