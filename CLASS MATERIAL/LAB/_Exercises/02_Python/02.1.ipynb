# %% [markdown]
# # Computations
#
# If you run a 10 kilometer race in 42 minutes 42 seconds,
# - What is your average pace (time per mile in minutes and seconds)?
# - What is your average speed in miles per hour?
#
# *Hint*: there are 1.61 kilometers in a mile.

# %%
# TODO at home

# %% [markdown]
# # Strings

# %% [markdown]
# 1. Define the following variables
# ```python
# sa = "ba"
# sb = "na"
# ```
# 2. Return the string "banana" by using the variables "sa" and "sb" defined above
# 3. Return the string "banana": use the string "sc" beloe and add two method calls to the string below. (hint: we saw differnt string methods: upper(), lower(), startswith(), replace()...)
# ```python
# sc = "beNeNe"
# ```

# %%
# TODO during class. Work in pair. (strategy 1). Choose this or the one below

# %% [markdown]
# # Dictionaries
#
#
# - Create a dictionary containing "name" and "surname" as keys, and inserting your information as values.
# - Add the student number (numero di matricola) information
# - Add some exams: which data structure are you going to use if you want to store both the name and the mark of each exam?
# - Retrieve the mark of a specific exam. If the exam has not been done, print 'NA'

# %%
# TODO during class. Work in pair. (strategy 2). Choose this or the one above

# %% [markdown]
# # Lists
# Consider the following list:
# ```python
# planets = ["Mercury", "Venus", "Earth", "Mars", "Jupiter", "Saturn", "Neptune", "Uranus"]
# ```
# - restore Pluto's status as a planet and add it to the list
# - use the slice operator to pull out the rocky planets (Mercury, Venus, Earth, Mars) as a new list
# - write a program to identify the first rocky planet in alphabetical order

# %%
# TODO at home
