# %% [markdown]
# # TASK
# STEP 0: define Goal: practice with visual data exploration

# %% [markdown]
# # Your turn. Work in pairs
# ### Scenario:
# Imagine that you two are married in the US state of Maine, and one of you is afraid that, if you eat too much margarina there is a high risk of divorce.
# <br><br>
# Let's call member "A" the "convincer" and member "B" the other member of the pair.
# <br>Member "A" needs data to convince member "B" (you have some data available in a dataframe).
# <br><br>Of course, you want to use a plot to motivate your theory.

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Data acquisition
#Per capita consumption of margarine (Pounds of margarine)
x1 = [8.2, 7, 6.5, 5.3, 5.2, 4, 4.6, 4.5, 4.2, 3.7]
#The divorce rate in Maine (Divorce rate)
x2 = [5, 4.7,4.6,4.4,4.3,4.1,4.2,4.2,4.2,4.1]
# Years of data collection
time = [2000,2001,2002,2003,2004,2005,2006,2007,2008, 2009]

#create a dataframe with data
df = pd.DataFrame(data= {"Per capita consumption of margarine":x1, "divorce rate in Maine": x2}, index=time)
df
# Out:
#       Per capita consumption of margarine  divorce rate in Maine
# 2000                                  8.2                    5.0
# 2001                                  7.0                    4.7
# 2002                                  6.5                    4.6
# 2003                                  5.3                    4.4
# 2004                                  5.2                    4.3
# 2005                                  4.0                    4.1
# 2006                                  4.6                    4.2
# 2007                                  4.5                    4.2
# 2008                                  4.2                    4.2
# 2009                                  3.7                    4.1

# %% [markdown]
# ### We introduced:
# - histograms
# - scatter plots (time-trends as a subset of)
# - boxplots
# - heatmap
# - sankey diagrams
# - pie-chart
# - radar char
# - ...

# %% [markdown]
# #### Matplotlib

# %% [markdown]
# if you want to use matplotlib, you could use some info from here...
#
# https://matplotlib.org/

# %% [markdown]
# #### Pandas - plotting

# %% [markdown]
# if you want to directly use pandas, you could use some info from here...
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html
#
# <br>
# or some hint from here:
# <br><br>
#
# <details>
# <summary>Click to reveal the answer</summary>
# import pandas as pd <br>
# import numpy as np <br>
#  <br>
# #given two  numpy arrays "x" and "y" <br>
#  <br>
# x = np.random.rand(50) <br>
# y = np.random.rand(50) <br>
#  <br>
# #Given a dataframe "df" <br>
# df = pd.DataFrame({'x':x, 'y':y}) <br>
# df.plot(kind='line') <br>
# df.plot(kind='bar') <br>
# df.plot(kind='scatter', x='x', y='y') <br>
# df.plot(kind='hist') <br>
# df.plot(kind='pie', x='x', y='y') <br>
# df.plot(kind='box', x='x') <br>
# </details>

# %% [markdown]
# #### Seaborn

# %% [markdown]
# if you want to use seaborn, you could use you could use some info from here..
#
# https://seaborn.pydata.org/

# %% [markdown]
# ## Your plot(s) here.

# %% [markdown]
# <details>
# <summary>One possible solution is hidden here</summary>
# df.plot(kind='scatter', x='Per capita consumption of margarine', y='divorce rate in Maine');
# </details>

# %% [markdown]
# ![margarina](divorce_margarina.jpg)

# %% [markdown]
# (https://www.tylervigen.com/spurious/correlation/5920_per-capita-consumption-of-margarine_correlates-with_the-divorce-rate-in-maine)<br>
# **AI explanation** <br>
# Perhaps as people used less margarine, they became less slippery in their relationships...
# Alternatively, it could be that as the margarine consumption decreased, so did the overall slickness in the state, leading to fewer instances of partners feeling like they couldn't grip the marriage.

# %% [markdown]
# Data from https://www.tylervigen.com/spurious/correlation/5920_per-capita-consumption-of-margarine_correlates-with_the-divorce-rate-in-maine
