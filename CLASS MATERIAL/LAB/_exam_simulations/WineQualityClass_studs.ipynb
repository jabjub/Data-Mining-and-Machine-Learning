# %% [markdown]
# # DMML exam: 2025-12-16

# %% [markdown]
# This dataset is composed of a red and white variants of the Portuguese "Vinho Verde" wine.
#
# Columns in the table contain
#
# - **target**
#     - quality - from 0 to 10
# - **attributes** numerical
#     1. fixed_acidity
#     2. volatile_acidity
#     3. citric_acid
#     4. residual_sugar
#     5. chlorides
#     6. free_sulfur_dioxide
#     7. total_sulfur_dioxide
#     8. density
#     9. pH
#     10. sulphates
#     11. alcohol

# %% [markdown]
# # Instructions summary
# 0. Rename this file as: *Surname_Name_StudentNumber.ipynb*
# 1. Import the *wine_quality.csv* dataset
# 2. Perform an **exploratory analysis**
#     - Report and discuss the results of the analysis
# 3. Formulate the binary classification problem
#     - Define a new column (name it **wine_goodness**) as *binarization* of the **quality** variable. The aim of the operation is to define two classes for the goodness of the wine: if the value of **quality** is higher than a cut-off value, the class is "1" or "True", otherwise the class is "0" or "False" (representing a *low* level of goodness). Use "6" as cut-off value.
#
# 4. Carry out a **classification analysis** aimed at predicting the **wine_goodness** class **based only on the input variables**, considering the following setting:
#     - Apply a 10-fold cross-validation procedure on the dataset (with shuffling) to identify the most suitable classifier among the following:
#         - DecisionTree classifier (default params)
#         - DecisionTree classifier (default params) after oversampling with SMOTE
#         - KNearestNeighbor classifier (default params)
#         - KNearestNeighbor classifier (default params) after feature selection targeted at keeping 7 features
#     - Report and discuss the results, motivating the choice of the most suitable model
#
# # Exam Delivery
# - Save the current file
# - Click "**Restart & Run All**" and check consistency (no error, expected results)
# - Export using
#      - "**File**" --> "**Download as**" --> "**HTML (.html)**"
# - Upload the following file in MS Teams Assignment
#      - HTML: *Surname_Name_StudentNumber.html*
#      - IPYNB: *Surname_Name_StudentNumber.ipynb*
#
# # Code of conduct
# - You can consult the course material (notebooks and slides)
# - You can consult the official documentation of the libraries
# - You cannot use generative AI tools (e.g., ChatGPT)
# - Any form of information leakage between candidates is not allowed: if this is ascertained, exam failure is automatic.

# %% [markdown]
# # 1. Import the *wine_quality.csv* dataset

# %%
#...

# %% [markdown]
# # 2. Perform an **exploratory analysis**
# - Report and discuss the results of the analysis.

# %%
#...

# %% [markdown]
# # 3. Formulate the binary classification problem

# %%
#...

# %% [markdown]
# # 4. Carry out a **classification analysis** aimed at predicting the **wine_goodness** class ** based only on the input variables**, considering the following setting
# - Apply a 10-fold cross-validation procedure on the dataset (with shuffling) to identify the most suitable classifier among the following:
#     - DecisionTree classifier (default params)
#     - DecisionTree classifier (default params) after oversampling with SMOTE
#     - KNearestNeighbor classifier (default params)
#     - KNearestNeighbor classifier (default params) after feature selection targeted at keeping 10 features
# - Report and discuss the results, motivating the choice of the most suitable model

# %%
# ...

# %% [markdown]
# # Exam Delivery
# - Save the current file
# - Click "**Restart & Run All**" and check consistency (no error, expected results)
# - Export using
#      - "**File**" --> "**Download as**" --> "**HTML (.html)**"
# - Upload the following file in MS Teams Assignment
#      - HTML: *Surname_Name_StudentNumber.html*
#      - IPYNB: *Surname_Name_StudentNumber.ipynb*
